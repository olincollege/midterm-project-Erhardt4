# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas
import matplotlib.pyplot as plt
import csv
import gapminder_data_manipulation

# %%
EIU_dataframe=pandas.read_csv('EIU_Democracy_Index.csv')
USA = EIU_dataframe.iloc[156,1:14]
USA.plot()
# Out:
# <AxesSubplot:>

# %%
for i in range(5):
    temp = EIU_dataframe.iloc[i, 1:14]
    temp.plot(legend=True)

# %%
r = csv.reader(open("EIU_Democracy_Index.csv", "r"))
country_list = []
#Countries List
counter = True
for row in r:
    if counter:
        yearList = row[1:]
        counter = False
    country_list.append(row[0])
country_list= country_list[1:]
#print(country_;ist)
#Years List


for i in range(len(year_list)):
    year_list[i] = int(year_list[i])
print(year_list)
# Out:
# [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

# %%
data = pandas.read_csv("EIU_Democracy_Index.csv")
gapminder_data_manipulation.get_year_list("EIU_Democracy_Index.csv")
# Out:
# [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

# %%
for i in range(10):
    temp = EIU_dataframe.iloc[i, 1:14]
    plt.plot(year_list, temp, marker =  '+')
    
plt.xlabel("Years")
plt.ylabel("EIU Democracy Index Value")
plt.xlim(2006, 2024)
plt.legend(country_list, loc = 'best')

# %%
chosenCountries = [1,3,5,70,160]
chosenCountriesNames = []
for index in chosenCountries:
    temp = EIU_dataframe.iloc[index,1:14]
    chosenCountriesNames.append(countryList[index])
    plt.plot(yearList, temp, marker =  '+')

plt.xlabel("Years")
plt.ylabel("EIU Democracy Index Value")
plt.xlim(2006, 2024)
plt.legend(chosenCountriesNames, loc = 'best')

# %%
import statistics
countriesAboveThreshold = []
threshold = .08#0.0632
for i in range(164):
    temp = EIU_dataframe.iloc[i,1:14]
    if statistics.pstdev(temp) > threshold:
        countriesAboveThreshold.append(i)
print(countriesAboveThreshold)
#findPopulationStandardDev(temp)

chosenCountriesNames = []
for index in countriesAboveThreshold:
    temp = EIU_dataframe.iloc[index,1:14]
    chosenCountriesNames.append(countryList[index])
    plt.plot(yearList, temp, marker =  '+')

plt.xlabel("Years")
plt.ylabel("EIU Democracy Index Value")
plt.xlim(2006, 2024)
plt.legend(chosenCountriesNames, loc = 'best')

#print(temp)
# Out:
# [21, 51, 86, 102, 149]

# %%
import gapminder_data_manipulation
import random

chosenCountryList = [21, 51, 86, 102, 149]
thresholdList = gapminder_data_manipulation.get_greatest_variance_countries(0)
#print(thresholdList)
#gapminder_data_manipulation.plot_chosen_countries(chosen_country_list)
#gapminder_data_manipulation.plot_chosen_countries(threshold_list)

randomList = []
for i in range(5):
    randomList.append(random.randint(1,165))
#print(randomList)
#gapminder_data_manipulation.plot_chosen_countries([86])
#gapminder_data_manipulation.plot_rate_chosen_countries(thresholdList)
print(gapminder_data_manipulation.get_rates([50, 100, 150]))
# Out:
# {'Ethiopia': [-2.1186440677966116, -2.1645021645021667, -9.292035398230096, -10.243902439024387, 2.9891304347826115, -1.84696569920843, 2.9569892473118005, -2.8720626631853525, 2.9569892473118005, -6.005221932114875, -4.999999999999989, -2.046783625730996], 'Morocco': [-0.2564102564102566, -0.2570694087403744, -1.0309278350515332, -1.3020833333333344, 1.0554089709762395, 6.2663185378590285, 0.0, -1.7199017199017212, 16.5, 2.3605150214592294, 2.0964360587002115, 2.464065708418882], 'Turkey': [0.0, -0.17543859649122825, 0.3514938488576648, 0.3502626970227479, 0.0, 0.5235602094241036, -2.2569444444444655, -9.05861456483125, 0.0, -1.5625000000000013, -3.174603174603177, -10.450819672131134]}

# %%
gapminder_data_manipulation.plot_histogram_all_years()

# %%
gapminder_data_manipulation.plot_histogram_all_data()
