# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas
import matplotlib.pyplot as plt
import csv

# %%
EIU_dataframe=pandas.read_csv('EIU_Democracy_Index.csv')
USA = EIU_dataframe.iloc[156,1:14]
USA.plot()

# %%
for i in range(5):
    temp = EIU_dataframe.iloc[i, 1:14]
    temp.plot(legend=True)

# %%
r = csv.reader(open("EIU_Democracy_Index.csv", "r"))
countryList = []
#Countries List
counter = True
for row in r:
    if counter:
        yearList = row[1:]
        counter = False
    countryList.append(row[0])
countryList= countryList[1:]
#print(countryList)
#Years List


for i in range(len(yearList)):
    yearList[i] = int(yearList[i])
print(yearList)

# %%
for i in range(10):
    temp = EIU_dataframe.iloc[i, 1:14]
    plt.plot(yearList, temp, marker =  '+')
    
plt.xlabel("Years")
plt.ylabel("EIU Democracy Index Value")
plt.xlim(2006, 2024)
plt.legend(countryList, loc = 'best')

# %%
chosenCountries = [1,3,5,70,160]
chosenCountriesNames = []
for index in chosenCountries:
    temp = EIU_dataframe.iloc[index,1:14]
    chosenCountriesNames.append(countryList[index])
    plt.plot(yearList, temp, marker =  '+')

plt.xlabel("Years")
plt.ylabel("EIU Democracy Index Value")
plt.xlim(2006, 2024)
plt.legend(chosenCountriesNames, loc = 'best')

# %%
import statistics
countriesAboveThreshold = []
threshold = .08#0.0632
for i in range(164):
    temp = EIU_dataframe.iloc[i,1:14]
    if statistics.pstdev(temp) > threshold:
        countriesAboveThreshold.append(i)
print(countriesAboveThreshold)
#findPopulationStandardDev(temp)

chosenCountriesNames = []
for index in countriesAboveThreshold:
    temp = EIU_dataframe.iloc[index,1:14]
    chosenCountriesNames.append(countryList[index])
    plt.plot(yearList, temp, marker =  '+')

plt.xlabel("Years")
plt.ylabel("EIU Democracy Index Value")
plt.xlim(2006, 2024)
plt.legend(chosenCountriesNames, loc = 'best')

#print(temp)

# %%
import gapMinderDataManipulation
import random

chosenCountryList = [21, 51, 86, 102, 149]
thresholdList = gapMinderDataManipulation.getGreatestVarianceCountries(0.09)
#gapMinderDataManipulation.plotChosenCountries(chosenCountryList)
#gapMinderDataManipulation.plotChosenCountries(thresholdList)

randomList = []
for i in range(5):
    randomList.append(random.randint(1,165))
print(randomList)
gapMinderDataManipulation.plotChosenCountries([86])
gapMinderDataManipulation.plotRateChosenCountries(thresholdList)
# Out:
# [115, 39, 13, 96, 113]

# %%
gapMinderDataManipulation.plotHistogramAllYears()

# %%
gapMinderDataManipulation.plotHistogramAllData()
# Out:
# [0.306, 0.304, 0.302, 0.275, 0.248, 0.248, 0.248, 0.248, 0.27699999999999997, 0.27699999999999997, 0.255, 0.255, 0.297, 0.591, 0.591, 0.591, 0.589, 0.586, 0.581, 0.5670000000000001, 0.5670000000000001, 0.5670000000000001, 0.591, 0.591, 0.598, 0.598, 0.317, 0.325, 0.332, 0.33799999999999997, 0.344, 0.344, 0.38299999999999995, 0.38299999999999995, 0.38299999999999995, 0.395, 0.35600000000000004, 0.35600000000000004, 0.35, 0.24100000000000002, 0.28800000000000003, 0.335, 0.33399999999999996, 0.332, 0.332, 0.335, 0.335, 0.335, 0.335, 0.34, 0.36200000000000004, 0.36200000000000004, 0.6629999999999999, 0.6629999999999999, 0.6629999999999999, 0.6729999999999999, 0.684, 0.684, 0.684, 0.684, 0.684, 0.7020000000000001, 0.696, 0.696, 0.7020000000000001, 0.415, 0.41200000000000003, 0.409, 0.409, 0.409, 0.409, 0.409, 0.402, 0.413, 0.4, 0.38799999999999996, 0.41100000000000003, 0.479, 0.909, 0.909, 0.909, 0.915, 0.922, 0.922, 0.922, 0.9129999999999999, 0.9009999999999999, 0.9009999999999999, 